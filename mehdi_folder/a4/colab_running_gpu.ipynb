# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# !ls "/content/drive/My Drive"

# %%
# !pip install -r "/content/drive/My Drive/a4/gpu_requirements.txt"

# %%
import os
os.chdir('/content/drive/My Drive/a4/')

# !ls
# Out:
# collect_submission.sh  model_embeddings.py  sanity_check_en_es_data
# en_es_data	       nmt_model.py	    sanity_check.py
# gpu_requirements.txt   outputs		    utils.py
# __init__.py	       __pycache__	    vocab.json
# local_env.yml	       README.md	    vocab.py
# model.bin	       run.py
# model.bin.optim        run.sh

# %%
# !sh run.sh train
# Out:
# Streaming output truncated to the last 5000 lines.
# epoch 7, iter 45190, avg. loss 30.93, avg. ppl 4.65 cum. examples 38080, speed 5096.27 words/sec, time elapsed 6011.05 sec
# epoch 7, iter 45200, avg. loss 30.79, avg. ppl 4.29 cum. examples 38400, speed 5067.26 words/sec, time elapsed 6012.38 sec
# epoch 7, iter 45210, avg. loss 28.97, avg. ppl 4.41 cum. examples 38720, speed 4885.26 words/sec, time elapsed 6013.66 sec
# epoch 7, iter 45220, avg. loss 30.24, avg. ppl 4.20 cum. examples 39040, speed 4983.44 words/sec, time elapsed 6015.01 sec
# epoch 7, iter 45230, avg. loss 29.19, avg. ppl 4.33 cum. examples 39360, speed 4907.94 words/sec, time elapsed 6016.31 sec
# epoch 7, iter 45240, avg. loss 31.39, avg. ppl 4.61 cum. examples 39680, speed 5237.69 words/sec, time elapsed 6017.57 sec
# epoch 7, iter 45250, avg. loss 30.62, avg. ppl 4.43 cum. examples 40000, speed 4979.16 words/sec, time elapsed 6018.89 sec
# ...

# %%
# !sh run.sh test
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# load test source sentences from [./en_es_data/test.es]
# load test target sentences from [./en_es_data/test.en]
# load model from model.bin
# Decoding: 100% 8064/8064 [05:54<00:00, 22.74it/s]
# Corpus BLEU: 35.59309775352572
